# %%
import sys
import statistics
from pathlib import Path

import numpy as np
import torch

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "table3_results":
    PROJECT_ROOT = PROJECT_ROOT.parent.parent
elif PROJECT_ROOT.name == "Replicability":
    PROJECT_ROOT = PROJECT_ROOT.parent

REPLICABILITY_DIR = PROJECT_ROOT / "Replicability"
SAMPLES_TABLE3_DIR = REPLICABILITY_DIR / "samples_table3"
SYMMETRY_PROTOCOL_DIR = PROJECT_ROOT / "Symmetry_Measurement_Protocol"
if str(SYMMETRY_PROTOCOL_DIR) not in sys.path:
    sys.path.append(str(SYMMETRY_PROTOCOL_DIR))

from ChamferDistance import chamfer_distance
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# **Replicability Note:**
#
# Some values may differ slightly when this notebook is rerun, as the point-cloud preparation process uses a point-sampling algorithm that may introduce minor variations.

# %% [markdown]
# # Original dataset

# %% [markdown]
# ## Airplane

# %%
one_airplane_input_original_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "original_DiT3D_airplane_original.pth"
one_airplane_input_mirrored_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "original_DiT3D_airplane_mirrored.pth"

one_airplane_files_original_objects = torch.load(one_airplane_input_original_objects).cpu().numpy()
one_airplane_files_mirrored_objects = torch.load(one_airplane_input_mirrored_objects).cpu().numpy()

one_cd_results_airplane = []
for i in range(len(one_airplane_files_original_objects)):
    original_pc = one_airplane_files_original_objects[i]
    mirrored_pc = one_airplane_files_mirrored_objects[i]

    if original_pc.shape[0] == 15000:
        pass

    cd_result = chamfer_distance(original_pc, mirrored_pc)
    one_cd_results_airplane.append(cd_result)

print("\nAverage mean " + str(len(one_airplane_files_original_objects)) + ":", statistics.mean(one_cd_results_airplane))
print("Average mean/max:", max(one_cd_results_airplane))
print("Average mean/min:", min(one_cd_results_airplane))
# Out:
# Average mean 1000: 0.11682118306392647
# Average mean/max: 0.5862913783176595
# Average mean/min: 0.028758666572362063

# %% [markdown]
# ## Car

# %%
one_car_input_original_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "original_DiT3D_car_original.pth"
one_car_input_mirrored_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "original_DiT3D_car_mirrored.pth"

one_car_files_original_objects = torch.load(one_car_input_original_objects).cpu().numpy()
one_car_files_mirrored_objects = torch.load(one_car_input_mirrored_objects).cpu().numpy()

one_cd_results_car = []
for i in range(len(one_car_files_original_objects)):
    original_pc = one_car_files_original_objects[i]
    mirrored_pc = one_car_files_mirrored_objects[i]

    if original_pc.shape[0] == 15000:
        pass

    cd_result = chamfer_distance(original_pc, mirrored_pc)
    one_cd_results_car.append(cd_result)

print("\nAverage mean " + str(len(one_car_files_original_objects)) + ":", statistics.mean(one_cd_results_car))
print("Average mean/max:", max(one_cd_results_car))
print("Average mean/min:", min(one_cd_results_car))
# Out:
# Average mean 1000: 0.1794459316743396
# Average mean/max: 2.5339248233940874
# Average mean/min: 0.03453310053898796

# %% [markdown]
# ## Chair

# %%
one_chair_input_original_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "original_DiT3D_chair_original.pth"
one_chair_input_mirrored_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "original_DiT3D_chair_mirrored.pth"

one_chair_files_original_objects = torch.load(one_chair_input_original_objects).cpu().numpy()
one_chair_files_mirrored_objects = torch.load(one_chair_input_mirrored_objects).cpu().numpy()

one_cd_results_chair = []
for i in range(len(one_chair_files_original_objects)):
    original_pc = one_chair_files_original_objects[i]
    mirrored_pc = one_chair_files_mirrored_objects[i]

    if original_pc.shape[0] == 15000:
        pass

    cd_result = chamfer_distance(original_pc, mirrored_pc)
    one_cd_results_chair.append(cd_result)

print("\nAverage mean " + str(len(one_chair_files_original_objects)) + ":", statistics.mean(one_cd_results_chair))
print("Average mean/max:", max(one_cd_results_chair))
print("Average mean/min:", min(one_cd_results_chair))
# Out:
# Average mean 1000: 0.13553267067248187
# Average mean/max: 0.5455522053744628
# Average mean/min: 0.03483114681780309

# %% [markdown]
# # Mirrored dataset

# %% [markdown]
# ## Airplane

# %%
two_airplane_input_original_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "mirrored_DiT3D_airplane_original.pth"
two_airplane_input_mirrored_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "mirrored_DiT3D_airplane_mirrored.pth"

two_airplane_files_original_objects = torch.load(two_airplane_input_original_objects).cpu().numpy()
two_airplane_files_mirrored_objects = torch.load(two_airplane_input_mirrored_objects).cpu().numpy()

two_cd_results_airplane = []
for i in range(len(two_airplane_files_original_objects)):
    original_pc = two_airplane_files_original_objects[i]
    mirrored_pc = two_airplane_files_mirrored_objects[i]

    if original_pc.shape[0] == 15000:
        pass

    cd_result = chamfer_distance(original_pc, mirrored_pc)
    two_cd_results_airplane.append(cd_result)

print("\nAverage mean " + str(len(two_airplane_files_original_objects)) + ":", statistics.mean(two_cd_results_airplane))
print("Average mean/max:", max(two_cd_results_airplane))
print("Average mean/min:", min(two_cd_results_airplane))
# Out:
# Average mean 1000: 0.1307713107072327
# Average mean/max: 0.8981872029352753
# Average mean/min: 0.022042059794768632

# %% [markdown]
# ## Car

# %%
two_car_input_original_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "mirrored_DiT3D_car_original.pth"
two_car_input_mirrored_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "mirrored_DiT3D_car_mirrored.pth"

two_car_files_original_objects = torch.load(two_car_input_original_objects).cpu().numpy()
two_car_files_mirrored_objects = torch.load(two_car_input_mirrored_objects).cpu().numpy()

two_cd_results_car = []
for i in range(len(two_car_files_original_objects)):
    original_pc = two_car_files_original_objects[i]
    mirrored_pc = two_car_files_mirrored_objects[i]

    if original_pc.shape[0] == 15000:
        pass

    cd_result = chamfer_distance(original_pc, mirrored_pc)
    two_cd_results_car.append(cd_result)

print("\nAverage mean " + str(len(two_car_files_original_objects)) + ":", statistics.mean(two_cd_results_car))
print("Average mean/max:", max(two_cd_results_car))
print("Average mean/min:", min(two_cd_results_car))
# Out:
# Average mean 1000: 0.6181039869722369
# Average mean/max: 1.873614153691987
# Average mean/min: 0.0375755002626043

# %% [markdown]
# ## Chair

# %%
two_chair_input_original_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "mirrored_DiT3D_chair_original.pth"
two_chair_input_mirrored_objects = SAMPLES_TABLE3_DIR / "DiT-3D" / "mirrored_DiT3D_chair_mirrored.pth"

two_chair_files_original_objects = torch.load(two_chair_input_original_objects).cpu().numpy()
two_chair_files_mirrored_objects = torch.load(two_chair_input_mirrored_objects).cpu().numpy()

two_cd_results_chair = []
for i in range(len(two_chair_files_original_objects)):
    original_pc = two_chair_files_original_objects[i]
    mirrored_pc = two_chair_files_mirrored_objects[i]

    if original_pc.shape[0] == 15000:
        pass

    cd_result = chamfer_distance(original_pc, mirrored_pc)
    two_cd_results_chair.append(cd_result)

print("\nAverage mean " + str(len(two_chair_files_original_objects)) + ":", statistics.mean(two_cd_results_chair))
print("Average mean/max:", max(two_cd_results_chair))
print("Average mean/min:", min(two_cd_results_chair))
# Out:
# 0.13805353080232857
# 0.12036577454089643
# 0.13346828055286555
# 0.09680976025557338
# 0.18600954237055728
# 0.05497647904426807
# 0.085227262757196
# 1.199410123813809
# 0.19532612189441373
# 0.11962888571188893
# 0.10304230019346414
# 0.0887325444475727
# 0.08572351302345341
# 0.0847021525672206
# 0.07904152623139368
# 0.19011026160983263
# 0.22779145103172208
# 0.09500894103486626
# 0.08827451385225384
# 0.0658259430082839
# 0.19268684941654723
# 0.10454753070793474
# 0.17252632214449556
# 0.0805343732408883
# 0.14049220168040663
# 0.14771281437316253
# 0.08954934032538539
# 0.167202987075795
# 0.07308130320974014
# 0.1147617140118995
# 0.19394856128597857
# 0.09853526850709719
# 0.68000947731361
# 0.13779808321274106
# 0.17989161312555974
# 0.12278085596200417
# 0.12096341766816437
# 1.8587505171400391
# 0.03963821620615374
# 0.1093181666542267
# 0.12438702137401458
# 3.970630661107384
# 0.6194169397399589
# 0.07680327051131323
# 0.12068495493930925
# 0.20743314783931777
# 0.13786720449119141
# 0.07678331335174207
# 0.1076728206713205
# 0.07789275368240525
# 0.1947838327267093
# 0.19917158400002838
# 0.08596052639096155
# 0.069836303288585
# 0.15159000413370158
# 0.1484645660847035
# 0.19914114157240653
# 0.20512390237986133
# 0.12894997848061018
# 0.06877870087975556
# 0.10821141520077927
# 0.1427740919803734
# 0.05395848172105143
# 0.10069351255097092
# 2.4609816950572996
# 0.09938549756781481
# 0.24849778611160844
# 0.12040812144027326
# 0.09172059291408248
# 0.18028775408170541
# 0.6622416986892393
# 0.08166213192959992
# 0.14318819642978775
# 0.1089977285771272
# 0.05551042182014505
# 0.15264843246923923
# 0.1478474222230308
# 0.19964575403329293
# 0.09811532141108117
# 0.07064515035610605
# 0.17220333650811565
# 0.11193710226044457
# 0.0877754954084503
# 0.1479823585844715
# 0.0834732281570971
# 0.6331227062887113
# 0.06332682668177184
# 0.10963562623258613
# 0.06978621413409952
# 0.07831524990451963
# 0.10148936410356832
# 0.06546834584948497
# 0.16219081670885166
# 0.12327137142145853
# 0.07645685152528985
# 0.06886530490015674
# 1.8183753621775585
# 0.12235600527604423
# 0.1568464185296024
# 0.14754112591984012
# 0.09550031330606451
# 0.12955528396743082
# 0.11893792549007481
# 0.10593775574103176
# 0.1358622449479581
# 0.20590696217627497
# 0.108937026943382
# 0.18325472827910744
# 0.09415073826386633
# 0.09700414011713314
# 0.16318690801630217
# 0.14357203083175504
# 0.15429566983090043
# 0.11732317045509323
# 0.13670985048642853
# 0.18015656825076298
# 0.0746056286652261
