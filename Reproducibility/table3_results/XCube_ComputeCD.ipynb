# %%
import os
import sys
import statistics
from pathlib import Path

import numpy as np

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "Table3_Results":
    PROJECT_ROOT = PROJECT_ROOT.parent.parent
elif PROJECT_ROOT.name == "Reproducibility":
    PROJECT_ROOT = PROJECT_ROOT.parent

SYMMETRY_PROTOCOL_DIR = PROJECT_ROOT / "Symmetry_Measurement_Protocol"
if str(SYMMETRY_PROTOCOL_DIR) not in sys.path:
    sys.path.append(str(SYMMETRY_PROTOCOL_DIR))

from ChamferDistance import chamfer_distance
from FarthestPointSampling import farthest_point_sampling
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Original dataset

# %% [markdown]
# ## Airplane

# %%
one_airplane_input_original_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/plane_original/coarse_original"
one_airplane_input_mirrored_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/plane_original/coarse_mirrored"

one_airplane_files_original_objects = sorted([f for f in os.listdir(one_airplane_input_original_objects) if f.endswith(".npy")])
one_airplane_files_mirrored_objects = sorted([f for f in os.listdir(one_airplane_input_mirrored_objects) if f.endswith(".npy")])

one_cd_results_airplane = []

for i in one_airplane_files_original_objects:
    file_path_pc_1 = os.path.join(one_airplane_input_original_objects, i)
    file_path_pc_2 = os.path.join(one_airplane_input_mirrored_objects, i)

    #print(file_path_pc_1)
    #print(file_path_pc_2)
    
    original_pc = np.load(file_path_pc_1)
    mirrored_pc = np.load(file_path_pc_2)

    if original_pc.shape[0] <= 2048:
        pass
    elif mirrored_pc.shape[0] >= 2048:
        original_pc = farthest_point_sampling(original_pc, 2048)
        mirrored_pc = farthest_point_sampling(mirrored_pc, 2048)  

    # Compute CD
    cd_result = chamfer_distance(original_pc, mirrored_pc)

    one_cd_results_airplane.append(cd_result)

print("\nAverage mean " + str(len(one_airplane_files_original_objects)) +":", statistics.mean(one_cd_results_airplane))
print("Average mean/max:", max(one_cd_results_airplane))
print("Average mean/min:", min(one_cd_results_airplane))
# Out:
# Average mean 1000: 0.08446460537380836
# Average mean/max: 0.3121724541903943
# Average mean/min: 0.007256231091863234

# %% [markdown]
# ## Car

# %%
one_car_input_original_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/car_original/coarse_original"
one_car_input_mirrored_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/car_original/coarse_mirrored"

one_car_files_original_objects = sorted([f for f in os.listdir(one_car_input_original_objects) if f.endswith(".npy")])
one_car_files_mirrored_objects = sorted([f for f in os.listdir(one_car_input_mirrored_objects) if f.endswith(".npy")])

one_cd_results_car = []

for i in one_car_files_original_objects:
    file_path_pc_1 = os.path.join(one_car_input_original_objects, i)
    file_path_pc_2 = os.path.join(one_car_input_mirrored_objects, i)

    #print(file_path_pc_1)
    #print(file_path_pc_2)
    
    original_pc = np.load(file_path_pc_1)
    mirrored_pc = np.load(file_path_pc_2)

    if original_pc.shape[0] <= 2048:
        pass
    elif mirrored_pc.shape[0] >= 2048:
        original_pc = farthest_point_sampling(original_pc, 2048)
        mirrored_pc = farthest_point_sampling(mirrored_pc, 2048)

    # Compute CD
    cd_result = chamfer_distance(original_pc, mirrored_pc)

    one_cd_results_car.append(cd_result)

print("\nAverage mean " + str(len(one_car_files_original_objects)) +":", statistics.mean(one_cd_results_car))
print("Average mean/max:", max(one_cd_results_car))
print("Average mean/min:", min(one_cd_results_car))
# Out:
# Average mean 1000: 0.06358232115119905
# Average mean/max: 0.23532878197003043
# Average mean/min: 0.0298475558768506

# %% [markdown]
# ## Chair

# %%
one_chair_input_original_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/chair_original/coarse_original"
one_chair_input_mirrored_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/chair_original/coarse_mirrored"

one_chair_files_original_objects = sorted([f for f in os.listdir(one_chair_input_original_objects) if f.endswith(".npy")])
one_chair_files_mirrored_objects = sorted([f for f in os.listdir(one_chair_input_mirrored_objects) if f.endswith(".npy")])

one_cd_results_chair = []

for i in one_chair_files_original_objects:
    file_path_pc_1 = os.path.join(one_chair_input_original_objects, i)
    file_path_pc_2 = os.path.join(one_chair_input_mirrored_objects, i)

    #print(file_path_pc_1)
    #print(file_path_pc_2)
    
    original_pc = np.load(file_path_pc_1)
    mirrored_pc = np.load(file_path_pc_2)

    if original_pc.shape[0] <= 2048:
        pass
    elif mirrored_pc.shape[0] >= 2048:
        original_pc = farthest_point_sampling(original_pc, 2048)
        mirrored_pc = farthest_point_sampling(mirrored_pc, 2048)

    # Compute CD
    cd_result = chamfer_distance(original_pc, mirrored_pc)

    one_cd_results_chair.append(cd_result)

print("\nAverage mean " + str(len(one_chair_files_original_objects)) +":", statistics.mean(one_cd_results_chair))
print("Average mean/max:", max(one_cd_results_chair))
print("Average mean/min:", min(one_cd_results_chair))
# Out:
# Average mean 1000: 0.2085317983861741
# Average mean/max: 0.5621633592829065
# Average mean/min: 0.038339277939648544

# %% [markdown]
# # Mirrored dataset

# %% [markdown]
# ## Airplane

# %%
two_airplane_input_original_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/plane_mirrored/coarse_original"
two_airplane_input_mirrored_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/plane_mirrored/coarse_mirrored"

two_airplane_files_original_objects = sorted([f for f in os.listdir(two_airplane_input_original_objects) if f.endswith(".npy")])
two_airplane_files_mirrored_objects = sorted([f for f in os.listdir(two_airplane_input_mirrored_objects) if f.endswith(".npy")])

two_cd_results_airplane = []

for i in two_airplane_files_original_objects:
    file_path_pc_1 = os.path.join(two_airplane_input_original_objects, i)
    file_path_pc_2 = os.path.join(two_airplane_input_mirrored_objects, i)

    #print(file_path_pc_1)
    #print(file_path_pc_2)
    
    original_pc = np.load(file_path_pc_1)
    mirrored_pc = np.load(file_path_pc_2)

    if original_pc.shape[0] <= 2048:
        pass
    elif mirrored_pc.shape[0] >= 2048:
        original_pc = farthest_point_sampling(original_pc, 2048)
        mirrored_pc = farthest_point_sampling(mirrored_pc, 2048)        

    # Compute CD
    cd_result = chamfer_distance(original_pc, mirrored_pc)

    two_cd_results_airplane.append(cd_result)

print("\nAverage mean " + str(len(two_airplane_files_original_objects)) +":", statistics.mean(two_cd_results_airplane))
print("Average mean/max:", max(two_cd_results_airplane))
print("Average mean/min:", min(two_cd_results_airplane))
# Out:
# Average mean 1000: 0.05280730028313174
# Average mean/max: 0.26880410500996865
# Average mean/min: 0.01340007601735596

# %% [markdown]
# ## Car

# %%
two_car_input_original_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/car_mirrored/coarse_original"
two_car_input_mirrored_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/car_mirrored/coarse_mirrored"

two_car_files_original_objects = sorted([f for f in os.listdir(two_car_input_original_objects) if f.endswith(".npy")])
two_car_files_mirrored_objects = sorted([f for f in os.listdir(two_car_input_mirrored_objects) if f.endswith(".npy")])

two_cd_results_car = []

for i in two_car_files_original_objects:
    file_path_pc_1 = os.path.join(two_car_input_original_objects, i)
    file_path_pc_2 = os.path.join(two_car_input_mirrored_objects, i)

    #print(file_path_pc_1)
    #print(file_path_pc_2)
    
    original_pc = np.load(file_path_pc_1)
    mirrored_pc = np.load(file_path_pc_2)

    if original_pc.shape[0] <= 2048:
        pass
    elif mirrored_pc.shape[0] >= 2048:
        original_pc = farthest_point_sampling(original_pc, 2048)
        mirrored_pc = farthest_point_sampling(mirrored_pc, 2048) 

    # Compute CD
    cd_result = chamfer_distance(original_pc, mirrored_pc)

    two_cd_results_car.append(cd_result)

print("\nAverage mean " + str(len(two_car_files_original_objects)) +":", statistics.mean(two_cd_results_car))
print("Average mean/max:", max(two_cd_results_car))
print("Average mean/min:", min(two_cd_results_car))
# Out:
# Average mean 1000: 0.060198321885905424
# Average mean/max: 0.26959702563753607
# Average mean/min: 0.022587633470094022

# %% [markdown]
# ## Chair

# %%
two_chair_input_original_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/chair_mirrored/coarse_original"
two_chair_input_mirrored_objects = "/home/ncaytuir/data/Datasets/Resultados_XCube/NewExp_ArchitectureAssessing/chair_mirrored/coarse_mirrored"

two_chair_files_original_objects = sorted([f for f in os.listdir(two_chair_input_original_objects) if f.endswith(".npy")])
two_chair_files_mirrored_objects = sorted([f for f in os.listdir(two_chair_input_mirrored_objects) if f.endswith(".npy")])

two_cd_results_chair = []

for i in two_chair_files_original_objects:
    file_path_pc_1 = os.path.join(two_chair_input_original_objects, i)
    file_path_pc_2 = os.path.join(two_chair_input_mirrored_objects, i)

    #print(file_path_pc_1)
    #print(file_path_pc_2)
    
    original_pc = np.load(file_path_pc_1)
    mirrored_pc = np.load(file_path_pc_2)

    if original_pc.shape[0] <= 2048:
        pass
    elif mirrored_pc.shape[0] >= 2048:
        original_pc = farthest_point_sampling(original_pc, 2048)
        mirrored_pc = farthest_point_sampling(mirrored_pc, 2048) 

    # Compute CD
    cd_result = chamfer_distance(original_pc, mirrored_pc)

    two_cd_results_chair.append(cd_result)

print("\nAverage mean " + str(len(two_chair_files_original_objects)) +":", statistics.mean(two_cd_results_chair))
print("Average mean/max:", max(two_cd_results_chair))
print("Average mean/min:", min(two_cd_results_chair))
# Out:
# Average mean 1000: 0.12620606157858738
# Average mean/max: 0.39608600965649815
# Average mean/min: 0.039448170788613277
