# %% [markdown]
# # Reproducibility: paper tables
#
# Notebook to reproduce result of Tables 1, 2, and 4 of the main paper [Symmetry Matters: Auditing and Symmetrizing 3D Generative Models](https://arxiv.org/abs/2512.18953). Result computations of Table 3 are in `Table3_Results`'s directory.
#
# Expected notebook outputs:
#
# - Cell outputs

# %%
import json
import numpy as np
from utils import *
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "Reproducibility":
    PROJECT_ROOT = PROJECT_ROOT.parent

REPRO_DIR = PROJECT_ROOT / "Reproducibility"

COMPUTED_NSCD_DIR = "computed_NSCD"
COMPUTED_NSCD_PER_EPOCH_DIR = "computed_NSCD_PER_EPOCHS"

print(f"PROJECT_ROOT = {PROJECT_ROOT}")
# Out:
# PROJECT_ROOT = /home/isipiran/Symmetrization-of-3D-Generative-Models

# %% [markdown]
# Load data from `.json` files from path and compute means

# %%
# ORIGINAL ShapeNet
file_path_airplane = f"{COMPUTED_NSCD_DIR}/shapenet_airplane.json"
shapenet1000_airplane_data = load_values_from_json(file_path_airplane)
airplane_mean = np.mean(shapenet1000_airplane_data)

file_path_car = f"{COMPUTED_NSCD_DIR}/shapenet_car.json"
shapenet1000_car_data = load_values_from_json(file_path_car)
car_mean = np.mean(shapenet1000_car_data)

file_path_chair = f"{COMPUTED_NSCD_DIR}/shapenet_chair.json"
shapenet1000_chair_data = load_values_from_json(file_path_chair)
chair_mean = np.mean(shapenet1000_chair_data)

# MIRRORED ShapeNet
file_path_airplane = f"{COMPUTED_NSCD_DIR}/cd_res_mirrored_airplane.json"
mirrored_shapenet1000_airplane_data = load_values_from_json(file_path_airplane)
mirrored_airplane_mean = np.mean(mirrored_shapenet1000_airplane_data)

file_path_car = f"{COMPUTED_NSCD_DIR}/cd_res_mirrored_car.json"
mirrored_shapenet1000_car_data = load_values_from_json(file_path_car)
mirrored_car_mean = np.mean(mirrored_shapenet1000_car_data)

file_path_chair = f"{COMPUTED_NSCD_DIR}/cd_res_mirrored_chair.json"
mirrored_shapenet1000_chair_data = load_values_from_json(file_path_chair)
mirrored_chair_mean = np.mean(mirrored_shapenet1000_chair_data)

# ORIGINAL MODEL RESULTS
## DPM
file_path = f"{COMPUTED_NSCD_DIR}/original_dpm_cd_results_airplane.json"
dpm_airplane_data = load_values_from_json(file_path)
dpm_original_airplane_mean = np.mean(dpm_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_dpm_cd_results_car.json"
dpm_car_data = load_values_from_json(file_path)
dpm_original_car_mean = np.mean(dpm_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_dpm_cd_results_chair.json"
dpm_chair_data = load_values_from_json(file_path)
dpm_original_chair_mean = np.mean(dpm_chair_data)

## PVD
file_path = f"{COMPUTED_NSCD_DIR}/original_pvd_cd_results_airplane.json"
pvd1000_airplane_data = load_values_from_json(file_path)
pvd_original_airplane_mean = np.mean(pvd1000_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_pvd_cd_results_car.json"
pvd1000_car_data = load_values_from_json(file_path)
pvd_original_car_mean = np.mean(pvd1000_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_pvd_cd_results_chair.json"
pvd1000_chair_data = load_values_from_json(file_path)
pvd_original_chair_mean = np.mean(pvd1000_chair_data)

## DiT-3D
file_path = f"{COMPUTED_NSCD_DIR}/original_dit-3d_cd_results_airplane.json"
dit_3d_airplane_data = load_values_from_json(file_path)
dit_3d_original_airplane_mean = np.mean(dit_3d_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_dit-3d_cd_results_car.json"
dit_3d_car_data = load_values_from_json(file_path)
dit_3d_original_car_mean = np.mean(dit_3d_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_dit-3d_cd_results_chair.json"
dit_3d_chair_data = load_values_from_json(file_path)
dit_3d_original_chair_mean = np.mean(dit_3d_chair_data)

## LION
file_path = f"{COMPUTED_NSCD_DIR}/original_lion_cd_results_airplane.json"
lion250_airplane_data = load_values_from_json(file_path)
lion_airplane_mean = np.mean(lion250_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_lion_cd_results_car.json"
lion250_car_data = load_values_from_json(file_path)
lion_car_mean = np.mean(lion250_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_lion_cd_results_chair.json"
lion250_chair_data = load_values_from_json(file_path)
lion_chair_mean = np.mean(lion250_chair_data)

## XCube
file_path = f"{COMPUTED_NSCD_DIR}/original_xcube_cd_results_airplane.json"
xcube1000_airplane_data = load_values_from_json(file_path)
xcube_airplane_mean = np.mean(xcube1000_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_xcube_cd_results_car.json"
xcube1000_car_data = load_values_from_json(file_path)
xcube_car_mean = np.mean(xcube1000_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_xcube_cd_results_chair.json"
xcube1000_chair_data = load_values_from_json(file_path)
xcube_chair_mean = np.mean(xcube1000_chair_data)

## SLIDE 3D
file_path = f"{COMPUTED_NSCD_DIR}/original_slide3d_cd_results_airplane.json"
slide1000_airplane_data = load_values_from_json(file_path)
slide_airplane_mean = np.mean(slide1000_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_slide3d_cd_results_car.json"
slide1000_car_data = load_values_from_json(file_path)
slide_car_mean = np.mean(slide1000_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_slide3d_cd_results_chair.json"
slide1000_chair_data = load_values_from_json(file_path)
slide_chair_mean = np.mean(slide1000_chair_data)

## SPVD-S
file_path = f"{COMPUTED_NSCD_DIR}/original_spvd-s_cd_results_airplane.json"
spvd_s_airplane_data = load_values_from_json(file_path)
spvd_s_original_airplane_mean = np.mean(spvd_s_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_spvd-s_cd_results_car.json"
spvd_s_car_data = load_values_from_json(file_path)
spvd_s_original_car_mean = np.mean(spvd_s_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_spvd-s_cd_results_chair.json"
spvd_s_chair_data = load_values_from_json(file_path)
spvd_s_original_chair_mean = np.mean(spvd_s_chair_data)

## SPVD-L
file_path = f"{COMPUTED_NSCD_DIR}/original_spvd-l_cd_results_airplane.json"
spvd_l_airplane_data = load_values_from_json(file_path)
spvd_l_original_airplane_mean = np.mean(spvd_l_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_spvd-l_cd_results_car.json"
spvd_l_car_data = load_values_from_json(file_path)
spvd_l_original_car_mean = np.mean(spvd_l_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/original_spvd-l_cd_results_chair.json"
spvd_l_chair_data = load_values_from_json(file_path)
spvd_l_original_chair_mean = np.mean(spvd_l_chair_data)

# MODELS TRAINED OVER MIRRORED OBJECTS DERIVED FROM SHAPENET
## DPM
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_dpm_cd_results_airplane.json"
dpm_mirrored_airplane_data = load_values_from_json(file_path)
dpm_mirrored_airplane_mean = np.mean(dpm_mirrored_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_dpm_cd_results_car.json"
dpm_mirrored_car_data = load_values_from_json(file_path)
dpm_mirrored_car_mean = np.mean(dpm_mirrored_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_dpm_cd_results_chair.json"
dpm_mirrored_chair_data = load_values_from_json(file_path)
dpm_mirrored_chair_mean = np.mean(dpm_mirrored_chair_data)

## PVD
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_pvd_cd_results_airplane.json"
pvd_mirrored_airplane_data = load_values_from_json(file_path)
pvd_mirrored_airplane_mean = np.mean(pvd_mirrored_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_pvd_cd_results_car.json"
pvd_mirrored_car_data = load_values_from_json(file_path)
pvd_mirrored_car_mean = np.mean(pvd_mirrored_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_pvd_cd_results_chair.json"
pvd_mirrored_chair_data = load_values_from_json(file_path)
pvd_mirrored_chair_mean = np.mean(pvd_mirrored_chair_data)

## DiT-3D
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_dit-3d_cd_results_airplane.json"
dit_3d_mirrored_airplane_data = load_values_from_json(file_path)
dit_3d_mirrored_airplane_mean = np.mean(dit_3d_mirrored_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_dit-3d_cd_results_car.json"
dit_3d_mirrored_car_data = load_values_from_json(file_path)
dit_3d_mirrored_car_mean = np.mean(dit_3d_mirrored_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_dit-3d_cd_results_chair.json"
dit_3d_mirrored_chair_data = load_values_from_json(file_path)
dit_3d_mirrored_chair_mean = np.mean(dit_3d_mirrored_chair_data)

## LION
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_lion_cd_results_airplane.json"
mirrored_lion250_airplane_data = load_values_from_json(file_path)
mirrored_lion_airplane_mean = np.mean(mirrored_lion250_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_lion_cd_results_car.json"
mirrored_lion250_car_data = load_values_from_json(file_path)
mirrored_lion_car_mean = np.mean(mirrored_lion250_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_lion_cd_results_chair.json"
mirrored_lion250_chair_data = load_values_from_json(file_path)
mirrored_lion_chair_mean = np.mean(mirrored_lion250_chair_data)

## XCube
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_xcube_cd_results_airplane.json"
mirrored_xcube1000_airplane_data = load_values_from_json(file_path)
mirrored_xcube_airplane_mean = np.mean(mirrored_xcube1000_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_xcube_cd_results_car.json"
mirrored_xcube1000_car_data = load_values_from_json(file_path)
mirrored_xcube_car_mean = np.mean(mirrored_xcube1000_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_xcube_cd_results_chair.json"
mirrored_xcube1000_chair_data = load_values_from_json(file_path)
mirrored_xcube_chair_mean = np.mean(mirrored_xcube1000_chair_data)

## SLIDE 3D
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_slide3d_cd_results_airplane.json"
mirrored_slide1000_airplane_data = load_values_from_json(file_path)
mirrored_slide_airplane_mean = np.mean(mirrored_slide1000_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_slide3d_cd_results_car.json"
mirrored_slide1000_car_data = load_values_from_json(file_path)
mirrored_slide_car_mean = np.mean(mirrored_slide1000_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_slide3d_cd_results_chair.json"
mirrored_slide1000_chair_data = load_values_from_json(file_path)
mirrored_slide_chair_mean = np.mean(mirrored_slide1000_chair_data)

## SPVD-S
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_spvd-s_cd_results_airplane.json"
spvd_s_mirrored_airplane_data = load_values_from_json(file_path)
spvd_s_mirrored_airplane_mean = np.mean(spvd_s_mirrored_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_spvd-s_cd_results_car.json"
spvd_s_mirrored_car_data = load_values_from_json(file_path)
spvd_s_mirrored_car_mean = np.mean(spvd_s_mirrored_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_spvd-s_cd_results_chair.json"
spvd_s_mirrored_chair_data = load_values_from_json(file_path)
spvd_s_mirrored_chair_mean = np.mean(spvd_s_mirrored_chair_data)

## SPVD-L
file_path = f"{COMPUTED_NSCD_DIR}/mirrored_spvd-l_cd_results_airplane.json"
spvd_l_mirrored_airplane_data = load_values_from_json(file_path)
spvd_l_mirrored_airplane_mean = np.mean(spvd_l_mirrored_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_spvd-l_cd_results_car.json"
spvd_l_mirrored_car_data = load_values_from_json(file_path)
spvd_l_mirrored_car_mean = np.mean(spvd_l_mirrored_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/mirrored_spvd-l_cd_results_chair.json"
spvd_l_mirrored_chair_data = load_values_from_json(file_path)
spvd_l_mirrored_chair_mean = np.mean(spvd_l_mirrored_chair_data)

# MODELS TRAINED OVER HALF-OBJECTS DATASET
## DPM
file_path = f"{COMPUTED_NSCD_DIR}/over-half_dpm_cd_results_airplane.json"
s_dpm_airplane_data = load_values_from_json(file_path)
s_dpm_airplane_mean = np.mean(s_dpm_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_dpm_cd_results_car.json"
s_dpm_car_data = load_values_from_json(file_path)
s_dpm_car_mean = np.mean(s_dpm_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_dpm_cd_results_chair.json"
s_dpm_chair_data = load_values_from_json(file_path)
s_dpm_chair_mean = np.mean(s_dpm_chair_data)

## PVD
file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_PVD_airplane.json"
s_pvd_airplane_data = load_values_from_json(file_path)
s_pvd_airplane_mean = np.mean(s_pvd_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_PVD_car.json"
s_pvd_car_data = load_values_from_json(file_path)
s_pvd_car_mean = np.mean(s_pvd_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_PVD_chair.json"
s_pvd_chair_data = load_values_from_json(file_path)
s_pvd_chair_mean = np.mean(s_pvd_chair_data)

## DiT-3D
file_path = f"{COMPUTED_NSCD_DIR}/over-half_dit-3d_cd_results_airplane.json"
s_dit_3d_airplane_data = load_values_from_json(file_path)
s_dit_3d_airplane_mean = np.mean(s_dit_3d_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_dit-3d_cd_results_car.json"
s_dit_3d_car_data = load_values_from_json(file_path)
s_dit_3d_car_mean = np.mean(s_dit_3d_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_dit-3d_cd_results_chair.json"
s_dit_3d_chair_data = load_values_from_json(file_path)
s_dit_3d_chair_mean = np.mean(s_dit_3d_chair_data)

## LION
file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_LION_airplane.json"
s_lion_airplane_data = load_values_from_json(file_path)
s_lion_airplane_mean = np.mean(s_lion_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_LION_car.json"
s_lion_car_data = load_values_from_json(file_path)
s_lion_car_mean = np.mean(s_lion_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_LION_chair.json"
s_lion_chair_data = load_values_from_json(file_path)
s_lion_chair_mean = np.mean(s_lion_chair_data)

## XCube
file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_XCube_airplane.json"
s_xcube_airplane_data = load_values_from_json(file_path)
s_xcube_airplane_mean = np.mean(s_xcube_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_XCube_car.json"
s_xcube_car_data = load_values_from_json(file_path)
s_xcube_car_mean = np.mean(s_xcube_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_XCube_chair.json"
s_xcube_chair_data = load_values_from_json(file_path)
s_xcube_chair_mean = np.mean(s_xcube_chair_data)

## SLIDE 3D
file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_SLIDE3D_airplane.json"
s_slide_airplane_data = load_values_from_json(file_path)
s_slide_airplane_mean = np.mean(s_slide_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_SLIDE3D_car.json"
s_slide_car_data = load_values_from_json(file_path)
s_slide_car_mean = np.mean(s_slide_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_cd_res_SLIDE3D_chair.json"
s_slide_chair_data = load_values_from_json(file_path)
s_slide_chair_mean = np.mean(s_slide_chair_data)

## SPVD-S
file_path = f"{COMPUTED_NSCD_DIR}/over-half_spvd_s_cd_results_airplane.json"
s_spvd_s_airplane_data = load_values_from_json(file_path)
s_spvd_s_airplane_mean = np.mean(s_spvd_s_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_spvd_s_cd_results_car.json"
s_spvd_s_car_data = load_values_from_json(file_path)
s_spvd_s_car_mean = np.mean(s_spvd_s_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_spvd_s_cd_results_chair.json"
s_spvd_s_chair_data = load_values_from_json(file_path)
s_spvd_s_chair_mean = np.mean(s_spvd_s_chair_data)

## SPVD-L
file_path = f"{COMPUTED_NSCD_DIR}/over-half_svpd_l_cd_results_airplane.json"
s_spvd_l_airplane_data = load_values_from_json(file_path)
s_spvd_l_airplane_mean = np.mean(s_spvd_l_airplane_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_svpd_l_cd_results_car.json"
s_spvd_l_car_data = load_values_from_json(file_path)
s_spvd_l_car_mean = np.mean(s_spvd_l_car_data)

file_path = f"{COMPUTED_NSCD_DIR}/over-half_svpd_l_cd_results_chair.json"
s_spvd_l_chair_data = load_values_from_json(file_path)
s_spvd_l_chair_mean = np.mean(s_spvd_l_chair_data)

# %% [markdown]
# ## Table 1: Mean symmetry scores ($𝜇_{𝑁𝑆𝐶𝐷}$) for generated samples

# %%
# Results are obtained from the data already loaded in the previous cell from computed_NSCD/*.json.
table1_data = {
    "DPM": {
        "airplane": {"Orig.": dpm_original_airplane_mean, "Mirr.": dpm_mirrored_airplane_mean},
        "car": {"Orig.": dpm_original_car_mean, "Mirr.": dpm_mirrored_car_mean},
        "chair": {"Orig.": dpm_original_chair_mean, "Mirr.": dpm_mirrored_chair_mean},
    },
    "PVD": {
        "airplane": {"Orig.": pvd_original_airplane_mean, "Mirr.": pvd_mirrored_airplane_mean},
        "car": {"Orig.": pvd_original_car_mean, "Mirr.": pvd_mirrored_car_mean},
        "chair": {"Orig.": pvd_original_chair_mean, "Mirr.": pvd_mirrored_chair_mean},
    },
    "LION": {
        "airplane": {"Orig.": lion_airplane_mean, "Mirr.": mirrored_lion_airplane_mean},
        "car": {"Orig.": lion_car_mean, "Mirr.": mirrored_lion_car_mean},
        "chair": {"Orig.": lion_chair_mean, "Mirr.": mirrored_lion_chair_mean},
    },
    "DiT-3D": {
        "airplane": {"Orig.": dit_3d_original_airplane_mean, "Mirr.": dit_3d_mirrored_airplane_mean},
        "car": {"Orig.": dit_3d_original_car_mean, "Mirr.": dit_3d_mirrored_car_mean},
        "chair": {"Orig.": dit_3d_original_chair_mean, "Mirr.": dit_3d_mirrored_chair_mean},
    },
    "XCube": {
        "airplane": {"Orig.": xcube_airplane_mean, "Mirr.": mirrored_xcube_airplane_mean},
        "car": {"Orig.": xcube_car_mean, "Mirr.": mirrored_xcube_car_mean},
        "chair": {"Orig.": xcube_chair_mean, "Mirr.": mirrored_xcube_chair_mean},
    },
    "SLIDE 3D": {
        "airplane": {"Orig.": slide_airplane_mean, "Mirr.": mirrored_slide_airplane_mean},
        "car": {"Orig.": slide_car_mean, "Mirr.": mirrored_slide_car_mean},
        "chair": {"Orig.": slide_chair_mean, "Mirr.": mirrored_slide_chair_mean},
    },
    "SPVD-S": {
        "airplane": {"Orig.": spvd_s_original_airplane_mean, "Mirr.": spvd_s_mirrored_airplane_mean},
        "car": {"Orig.": spvd_s_original_car_mean, "Mirr.": spvd_s_mirrored_car_mean},
        "chair": {"Orig.": spvd_s_original_chair_mean, "Mirr.": spvd_s_mirrored_chair_mean},
    },
    "SPVD-L": {
        "airplane": {"Orig.": spvd_l_original_airplane_mean, "Mirr.": spvd_l_mirrored_airplane_mean},
        "car": {"Orig.": spvd_l_original_car_mean, "Mirr.": spvd_l_mirrored_car_mean},
        "chair": {"Orig.": spvd_l_original_chair_mean, "Mirr.": spvd_l_mirrored_chair_mean},
    },
}

header_groups = [(CATEGORY_LABELS[c], ["Orig.", "Mirr."]) for c in CATEGORIES]
table1_rows = []
for model in MODELS:
    values = []
    for category in CATEGORIES:
        values.append(fmt4(table1_data[model][category]["Orig."]))
        values.append(fmt4(table1_data[model][category]["Mirr."]))
    table1_rows.append((model, values))

table1 = render_table("Table 1. Mean symmetry scores (mu_NSCD) for generated samples.", header_groups, table1_rows)
# Out:
# <style>
# .paper-table {border-collapse: collapse; font-family: serif; font-size: 14px; margin: 12px 0;}
# .paper-table th, .paper-table td {padding: 4px 10px; text-align: right; border-bottom: 1px solid #ddd;}
# .paper-table th:first-child, .paper-table td:first-child {text-align: left; font-weight: 600;}
# .paper-table thead tr:first-child th {border-bottom: 2px solid #222;}
# .paper-table caption {caption-side: top; text-align: left; font-weight: 700; font-size: 16px; margin-bottom: 6px;}
# </style>
# <table class='paper-table'><caption>Table 1. Mean symmetry scores (mu_NSCD) for generated samples.</caption><thead><tr><th rowspan='2'>Model</th><th colspan='2'>Airplane</th><th colspan='2'>Car</th><th colspan='2'>Chair</th></tr><tr><th>Orig.</th><th>Mirr.</th><th>Orig.</th><th>Mirr.</th><th>Orig.</th><th>Mirr.</th></tr></thead><tbody><tr><td>DPM</td><td>0.0156</td><td>0.0158</td><td>0.0302</td><td>0.0311</td><td>0.0280</td><td>0.0289</td></tr><tr><td>PVD</td><td>0.0155</td><td>0.0155</td><td>0.0297</td><td>0.0296</td><td>0.0278</td><td>0.0275</td></tr><tr><td>LION</td><td>0.0142</td><td>0.0151</td><td>0.0290</td><td>0.0291</td><td>0.0271</td><td>0.0269</td></tr><tr><td>DiT-3D</td><td>0.0262</td><td>0.0247</td><td>0.0301</td><td>0.0218</td><td>0.0259</td><td>0.0176</td></tr><tr><td>XCube</td><td>0.0106</td><td>0.0152</td><td>0.0209</td><td>0.0257</td><td>0.0190</td><td>0.0242</td></tr><tr><td>SLIDE 3D</td><td>0.0123</td><td>0.1190</td><td>0.0211</td><td>0.0495</td><td>0.0211</td><td>0.0624</td></tr><tr><td>SPVD-S</td><td>0.0289</td><td>0.0188</td><td>0.0288</td><td>0.0315</td><td>0.0287</td><td>0.0301</td></tr><tr><td>SPVD-L</td><td>0.0283</td><td>0.0158</td><td>0.0276</td><td>0.0310</td><td>0.0292</td><td>0.0323</td></tr></tbody></table>

# %% [markdown]
# ## Table 2: Symmetry preservation results

# %%
# Results are computed from Table 1 means and the ShapeNet / mirrored-ShapeNet means already loaded from computed_NSCD/*.json.
ground_truth_means = {
    "airplane": {"Orig.": airplane_mean, "Mirr.": mirrored_airplane_mean},
    "car": {"Orig.": car_mean, "Mirr.": mirrored_car_mean},
    "chair": {"Orig.": chair_mean, "Mirr.": mirrored_chair_mean},
}

header_groups = [(CATEGORY_LABELS[c], ["Delta_1", "Delta_2"]) for c in CATEGORIES]
table2_rows = []
for model in MODELS:
    values = []
    for category in CATEGORIES:
        delta_1 = abs(ground_truth_means[category]["Orig."] - table1_data[model][category]["Orig."])
        delta_2 = abs(ground_truth_means[category]["Mirr."] - table1_data[model][category]["Mirr."])
        values.append(fmt4(delta_1))
        values.append(fmt4(delta_2))
    table2_rows.append((model, values))

table2 = render_table("Table 2. Symmetry preservation results.", header_groups, table2_rows)
# Out:
# <style>
# .paper-table {border-collapse: collapse; font-family: serif; font-size: 14px; margin: 12px 0;}
# .paper-table th, .paper-table td {padding: 4px 10px; text-align: right; border-bottom: 1px solid #ddd;}
# .paper-table th:first-child, .paper-table td:first-child {text-align: left; font-weight: 600;}
# .paper-table thead tr:first-child th {border-bottom: 2px solid #222;}
# .paper-table caption {caption-side: top; text-align: left; font-weight: 700; font-size: 16px; margin-bottom: 6px;}
# </style>
# <table class='paper-table'><caption>Table 2. Symmetry preservation results.</caption><thead><tr><th rowspan='2'>Model</th><th colspan='2'>Airplane</th><th colspan='2'>Car</th><th colspan='2'>Chair</th></tr><tr><th>Delta_1</th><th>Delta_2</th><th>Delta_1</th><th>Delta_2</th><th>Delta_1</th><th>Delta_2</th></tr></thead><tbody><tr><td>DPM</td><td>0.0054</td><td>0.0064</td><td>0.0083</td><td>0.0113</td><td>0.0090</td><td>0.0117</td></tr><tr><td>PVD</td><td>0.0053</td><td>0.0061</td><td>0.0079</td><td>0.0098</td><td>0.0088</td><td>0.0104</td></tr><tr><td>LION</td><td>0.0041</td><td>0.0058</td><td>0.0072</td><td>0.0093</td><td>0.0081</td><td>0.0097</td></tr><tr><td>DiT-3D</td><td>0.0161</td><td>0.0154</td><td>0.0083</td><td>0.0020</td><td>0.0069</td><td>0.0004</td></tr><tr><td>XCube</td><td>0.0004</td><td>0.0059</td><td>0.0009</td><td>0.0059</td><td>0.0001</td><td>0.0070</td></tr><tr><td>SLIDE 3D</td><td>0.0021</td><td>0.1096</td><td>0.0008</td><td>0.0298</td><td>0.0021</td><td>0.0453</td></tr><tr><td>SPVD-S</td><td>0.0188</td><td>0.0094</td><td>0.0069</td><td>0.0117</td><td>0.0096</td><td>0.0129</td></tr><tr><td>SPVD-L</td><td>0.0182</td><td>0.0064</td><td>0.0057</td><td>0.0112</td><td>0.0102</td><td>0.0151</td></tr></tbody></table>

# %% [markdown]
# ## Table 3: Quantitative comparison of the symmetry-breaking inspection

# %%
import re

TABLE3_RESULTS_DIR = REPRO_DIR / "Table3_Results"


def average_means_from_notebook(notebook_path, expected_values=6):
    notebook_path = Path(notebook_path)

    notebook = json.loads(notebook_path.read_text(encoding="utf-8"))
    stream_text = []
    for cell in notebook.get("cells", []):
        for output in cell.get("outputs", []):
            if output.get("output_type") == "stream":
                stream_text.append("".join(output.get("text", [])))

    values = [
        float(match.group(1))
        for match in re.finditer(r"Average mean\s+\d+:\s+([0-9.eE+-]+)", "\n".join(stream_text))
    ]
    if len(values) != expected_values:
        raise ValueError(
            f"Expected {expected_values} saved 'Average mean' outputs in {notebook_path}, found {len(values)}. "
            "Run that notebook or check its saved outputs."
        )
    return values


def table3_values_from_notebook(notebook_path):
    values = average_means_from_notebook(notebook_path)
    return {
        "airplane": {"Orig.": values[0], "Mirr.": values[3]},
        "car": {"Orig.": values[1], "Mirr.": values[4]},
        "chair": {"Orig.": values[2], "Mirr.": values[5]},
    }

table3_sources = {
    "DPM": TABLE3_RESULTS_DIR / "DPM_ComputeCD.ipynb",
    "PVD": TABLE3_RESULTS_DIR / "PVD_ComputeCD.ipynb",
    "DiT-3D": TABLE3_RESULTS_DIR / "DiT-3D_ComputeCD.ipynb",
    "XCube": TABLE3_RESULTS_DIR / "XCube_ComputeCD.ipynb",
    "SLIDE 3D": TABLE3_RESULTS_DIR / "SLIDE3D_ComputeCD.ipynb",
    "SPVD-S": TABLE3_RESULTS_DIR / "SPVD-S_ComputeCD.ipynb",
    "SPVD-L": TABLE3_RESULTS_DIR / "SPVD-L_ComputeCD.ipynb",
    "LION (E)": TABLE3_RESULTS_DIR / "GenerateLatent_fromVAE.ipynb",
}

table3_data = {model: table3_values_from_notebook(path) for model, path in table3_sources.items()}

header_groups = [(CATEGORY_LABELS[c], ["Orig.", "Mirr."]) for c in CATEGORIES]
table3_rows = []
for model in table3_sources:
    values = []
    for category in CATEGORIES:
        values.append(fmt4(table3_data[model][category]["Orig."]))
        values.append(fmt4(table3_data[model][category]["Mirr."]))
    table3_rows.append((model, values))

table3 = render_table("Table 3. Quantitative comparison of the symmetry-breaking inspection.", header_groups, table3_rows)
# Out:
# <style>
# .paper-table {border-collapse: collapse; font-family: serif; font-size: 14px; margin: 12px 0;}
# .paper-table th, .paper-table td {padding: 4px 10px; text-align: right; border-bottom: 1px solid #ddd;}
# .paper-table th:first-child, .paper-table td:first-child {text-align: left; font-weight: 600;}
# .paper-table thead tr:first-child th {border-bottom: 2px solid #222;}
# .paper-table caption {caption-side: top; text-align: left; font-weight: 700; font-size: 16px; margin-bottom: 6px;}
# </style>
# <table class='paper-table'><caption>Table 3. Quantitative comparison of the symmetry-breaking inspection.</caption><thead><tr><th rowspan='2'>Model</th><th colspan='2'>Airplane</th><th colspan='2'>Car</th><th colspan='2'>Chair</th></tr><tr><th>Orig.</th><th>Mirr.</th><th>Orig.</th><th>Mirr.</th><th>Orig.</th><th>Mirr.</th></tr></thead><tbody><tr><td>DPM</td><td>0.0491</td><td>0.0509</td><td>0.0721</td><td>0.0738</td><td>0.0841</td><td>0.0856</td></tr><tr><td>PVD</td><td>0.0613</td><td>0.0618</td><td>0.0617</td><td>0.0610</td><td>0.1457</td><td>0.1418</td></tr><tr><td>DiT-3D</td><td>0.1168</td><td>0.1308</td><td>0.1794</td><td>0.6181</td><td>0.1355</td><td>0.2102</td></tr><tr><td>XCube</td><td>0.0845</td><td>0.0528</td><td>0.0636</td><td>0.0602</td><td>0.2085</td><td>0.1262</td></tr><tr><td>SLIDE 3D</td><td>0.0042</td><td>0.0436</td><td>0.0102</td><td>0.0326</td><td>0.0141</td><td>0.1008</td></tr><tr><td>SPVD-S</td><td>0.0299</td><td>0.0672</td><td>0.0624</td><td>0.0526</td><td>0.1426</td><td>0.1269</td></tr><tr><td>SPVD-L</td><td>0.0520</td><td>0.0542</td><td>0.0460</td><td>0.0599</td><td>0.1619</td><td>0.1500</td></tr><tr><td>LION (E)</td><td>0.1209</td><td>0.0687</td><td>0.0768</td><td>0.0501</td><td>0.0861</td><td>0.0438</td></tr></tbody></table>

# %% [markdown]
# ## Table 4: Generation results on Airplane, Car, and Chair compared with original models’ results using 1-NNA↓ and COV↑ as metrics.

# %%
import json
from html import escape
from pathlib import Path
from IPython.display import HTML, display

TABLE4_RESULTS_DIR = REPRO_DIR / "metric_results"
TABLE4_FILES = {
    "Original": TABLE4_RESULTS_DIR / "original_models.json",
    "HM": TABLE4_RESULTS_DIR / "mirrored-object_models.json",
    "S": TABLE4_RESULTS_DIR / "symmetrical_models.json",
}
TABLE4_FAMILY_ORDER = ["DPM", "PVD", "LION", "DiT-3D", "XCube", "SLIDE 3D", "SPVD-S", "SPVD-L"]
TABLE4_FAMILY_TO_KEY = {
    "DPM": "dpm",
    "PVD": "pvd",
    "LION": "lion",
    "DiT-3D": "dit3d",
    "XCube": "xcube",
    "SLIDE 3D": "slide3d",
    "SPVD-S": "spvd_s",
    "SPVD-L": "spvd_l",
}


def load_table4_results(json_path):
    results = json.loads(Path(json_path).read_text(encoding="utf-8"))
    grouped = {}
    for sample_path, metrics in results.items():
        stem = Path(sample_path).stem
        if stem.startswith("generated_ours_"):
            suffix = stem[len("generated_ours_"):]
        elif stem.startswith("generated_"):
            suffix = stem[len("generated_"):]
        elif stem.startswith("ablation_"):
            suffix = stem[len("ablation_"):]
        else:
            raise ValueError(f"Unexpected sample name in Table 4 data: {sample_path}")
        family_key, category = suffix.rsplit("_", 1)
        grouped.setdefault(family_key, {})[category] = metrics
    return grouped


def table4_cell(metrics, key):
    return fmt2(metrics[key] * 100.0)


variant_results = {variant: load_table4_results(path) for variant, path in TABLE4_FILES.items()}

table4_rows = []
for family_label in TABLE4_FAMILY_ORDER:
    family_key = TABLE4_FAMILY_TO_KEY[family_label]
    for variant_label, row_prefix in [("Original", ""), ("HM", "HM-"), ("S", "S-")]:
        family_results = variant_results[variant_label][family_key]
        row_name = f"{row_prefix}{family_label}"
        row_values = []
        for category in CATEGORIES:
            metrics = family_results[category]
            row_values.extend([
                table4_cell(metrics, "1-NN-CD-acc"),
                table4_cell(metrics, "1-NN-EMD-acc"),
                table4_cell(metrics, "lgan_cov-CD"),
                table4_cell(metrics, "lgan_cov-EMD"),
            ])
        table4_rows.append((row_name, row_values, variant_label, family_label))

table4_html = [
    TABLE_STYLE,
    "<style>",
    ".paper-table thead tr:nth-child(1) th { border-bottom: 1px solid #ddd; }",
    ".paper-table thead tr:nth-child(2) th { border-bottom: 1px solid #ddd; }",
    ".paper-table thead tr:nth-child(3) th { border-bottom: 2px solid #222; }",
    ".paper-table tbody tr.group-start td { border-top: 2px solid #444; }",
    ".paper-table tbody tr.variant-s td:first-child { font-style: italic; }",
    "</style>",
    "<table class='paper-table'>",
    "<caption>Table 4. Generation results on Airplane, Car, and Chair compared with original models' results using 1-NNA↓ and COV↑ as metrics.</caption>",
    "<thead>",
    "<tr><th rowspan='3'>Model</th>",
    "".join(f"<th colspan='4'>{CATEGORY_LABELS[category]}</th>" for category in CATEGORIES),
    "</tr>",
    "<tr>",
    "".join("<th colspan='2'>1-NNA (↓)</th><th colspan='2'>COV (↑)</th>" for _ in CATEGORIES),
    "</tr>",
    "<tr>",
    "".join("<th>CD</th><th>EMD</th><th>CD</th><th>EMD</th>" for _ in CATEGORIES),
    "</tr>",
    "</thead><tbody>",
]

for row_name, row_values, variant_label, family_label in table4_rows:
    row_classes = [f"variant-{variant_label.lower()}"]
    if variant_label == "Original" and family_label != TABLE4_FAMILY_ORDER[0]:
        row_classes.append("group-start")
    class_attr = " ".join(row_classes)
    table4_html.append(f"<tr class='{class_attr}'><td>{escape(row_name)}</td>")
    for value in row_values:
        table4_html.append(f"<td>{value}</td>")
    table4_html.append("</tr>")

table4_html.append("</tbody></table>")
display(HTML("".join(table4_html)))

table4 = {
    "title": "Table 4. Generation results on Airplane, Car, and Chair compared with original models' results using 1-NNA↓ and COV↑ as metrics.",
    "rows": table4_rows,
}
# Out:
# <style>
# .paper-table {border-collapse: collapse; font-family: serif; font-size: 14px; margin: 12px 0;}
# .paper-table th, .paper-table td {padding: 4px 10px; text-align: right; border-bottom: 1px solid #ddd;}
# .paper-table th:first-child, .paper-table td:first-child {text-align: left; font-weight: 600;}
# .paper-table thead tr:first-child th {border-bottom: 2px solid #222;}
# .paper-table caption {caption-side: top; text-align: left; font-weight: 700; font-size: 16px; margin-bottom: 6px;}
# </style>
# <style>.paper-table thead tr:nth-child(1) th { border-bottom: 1px solid #ddd; }.paper-table thead tr:nth-child(2) th { border-bottom: 1px solid #ddd; }.paper-table thead tr:nth-child(3) th { border-bottom: 2px solid #222; }.paper-table tbody tr.group-start td { border-top: 2px solid #444; }.paper-table tbody tr.variant-s td:first-child { font-style: italic; }</style><table class='paper-table'><caption>Table 4. Generation results on Airplane, Car, and Chair compared with original models' results using 1-NNA↓ and COV↑ as metrics.</caption><thead><tr><th rowspan='3'>Model</th><th colspan='4'>Airplane</th><th colspan='4'>Car</th><th colspan='4'>Chair</th></tr><tr><th colspan='2'>1-NNA (↓)</th><th colspan='2'>COV (↑)</th><th colspan='2'>1-NNA (↓)</th><th colspan='2'>COV (↑)</th><th colspan='2'>1-NNA (↓)</th><th colspan='2'>COV (↑)</th></tr><tr><th>CD</th><th>EMD</th><th>CD</th><th>EMD</th><th>CD</th><th>EMD</th><th>CD</th><th>EMD</th><th>CD</th><th>EMD</th><th>CD</th><th>EMD</th></tr></thead><tbody><tr class='variant-original'><td>DPM</td><td>87.13</td><td>88.49</td><td>44.31</td><td>30.45</td><td>77.31</td><td>69.94</td><td>31.50</td><td>36.42</td><td>64.84</td><td>72.92</td><td>40.97</td><td>37.52</td></tr><tr class='variant-hm'><td>HM-DPM</td><td>86.01</td><td>80.20</td><td>43.56</td><td>38.86</td><td>75.29</td><td>70.09</td><td>32.66</td><td>36.13</td><td>63.81</td><td>71.27</td><td>44.74</td><td>40.03</td></tr><tr class='variant-s'><td>S-DPM</td><td>90.22</td><td>85.02</td><td>41.58</td><td>37.62</td><td>70.52</td><td>69.65</td><td>27.17</td><td>37.57</td><td>64.44</td><td>69.78</td><td>41.76</td><td>41.44</td></tr><tr class='variant-original group-start'><td>PVD</td><td>79.46</td><td>71.16</td><td>43.32</td><td>47.77</td><td>62.72</td><td>52.46</td><td>40.75</td><td>49.71</td><td>57.38</td><td>55.73</td><td>45.53</td><td>48.98</td></tr><tr class='variant-hm'><td>HM-PVD</td><td>85.40</td><td>81.44</td><td>41.83</td><td>37.87</td><td>65.17</td><td>57.66</td><td>41.33</td><td>47.40</td><td>58.32</td><td>59.50</td><td>44.11</td><td>50.86</td></tr><tr class='variant-s'><td>S-PVD</td><td>96.29</td><td>93.44</td><td>18.81</td><td>19.06</td><td>62.72</td><td>61.13</td><td>41.91</td><td>45.66</td><td>57.69</td><td>60.99</td><td>45.84</td><td>47.10</td></tr><tr class='variant-original group-start'><td>LION</td><td>77.60</td><td>67.70</td><td>43.56</td><td>45.30</td><td>64.02</td><td>55.35</td><td>43.35</td><td>50.58</td><td>58.87</td><td>56.67</td><td>43.80</td><td>46.78</td></tr><tr class='variant-hm'><td>HM-LION</td><td>85.89</td><td>83.42</td><td>36.88</td><td>35.64</td><td>69.08</td><td>64.31</td><td>36.99</td><td>43.35</td><td>65.54</td><td>65.93</td><td>39.72</td><td>42.70</td></tr><tr class='variant-s'><td>S-LION</td><td>82.67</td><td>78.84</td><td>39.60</td><td>37.38</td><td>63.01</td><td>61.13</td><td>38.15</td><td>42.49</td><td>62.32</td><td>60.28</td><td>44.27</td><td>46.47</td></tr><tr class='variant-original group-start'><td>DiT-3D</td><td>99.01</td><td>99.01</td><td>9.41</td><td>10.15</td><td>97.54</td><td>96.68</td><td>10.12</td><td>19.94</td><td>62.87</td><td>61.07</td><td>37.05</td><td>44.90</td></tr><tr class='variant-hm'><td>HM-DiT-3D</td><td>99.13</td><td>99.26</td><td>8.42</td><td>7.92</td><td>94.36</td><td>93.35</td><td>17.05</td><td>23.99</td><td>60.99</td><td>62.72</td><td>39.40</td><td>44.43</td></tr><tr class='variant-s'><td>S-DiT-3D</td><td>83.17</td><td>76.49</td><td>44.31</td><td>39.36</td><td>63.44</td><td>63.58</td><td>36.99</td><td>41.62</td><td>62.95</td><td>64.99</td><td>43.17</td><td>42.86</td></tr><tr class='variant-original group-start'><td>XCube</td><td>84.78</td><td>87.50</td><td>38.86</td><td>31.44</td><td>69.80</td><td>75.00</td><td>38.15</td><td>42.49</td><td>52.28</td><td>58.87</td><td>48.35</td><td>48.51</td></tr><tr class='variant-hm'><td>HM-XCube</td><td>84.16</td><td>89.23</td><td>40.35</td><td>33.66</td><td>69.80</td><td>74.86</td><td>38.44</td><td>39.60</td><td>52.20</td><td>58.63</td><t ...
